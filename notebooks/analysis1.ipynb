# %% [markdown]
# # Andrew Liawan

# %% [markdown]
# ## Research question/interests
#
# #### How does an artist hold up in 2020 in terms of the recognizability of their song(s) among two different generations, the millenials and the gen-Z?
#
# #### My interest is not focused on the individual songs themselves, but rather focusing on the recognizability of the artists themselves, by grouping the songs based on the artists, and evaluating the difference of recognizability of their songs in 2020 between the two generations, since a person who recognized a 90s song will most likely recognize the artist who sang or created the songs.

# %%
import pandas as pd

# %%
nineties = pd.read_csv("../data/raw/time_series_90s.csv")
gen = pd.read_csv("../data/raw/recognition_by_generation.csv")
df = nineties.merge(gen)
df
# Out:
#               artist                song  years_old_13  years_old_12  \
# 0              2 Pac     California Love      0.647859      0.540000
# 1               2Pac    How Do U Want It      0.265027      0.226415
# 2                702  Where My Girls At?      0.630772      0.614286
# 3        Ace Of Base  All That She Wants      0.962963      0.940000
# 4        Ace Of Base   Don't Turn Around      0.899068      0.909091
# ..               ...                 ...           ...           ...
# 339  Wilson Phillips          Release Me      0.695963      0.783784
# 340  Wilson Phillips      You're In Love      0.505111      0.500000
# 341  Wreckx-N-Effect         Rump Shaker      0.776325      0.745098
# 342           Xscape     Just Kickin' It      0.188492      0.161290
# 343         diVINYLS      I Touch Myself      0.709179      0.625000
#
#      years_old_11  years_old_10  years_old_9  years_old_8  years_old_7  \
# 0        0.711864      0.435484     0.644444     0.594203     0.600000
# 1        0.382353      0.296296     0.229730     0.283582     0.138889
# 2        0.660377      0.415385     0.532258     0.375000     0.415094
# 3        0.976190      0.877193     0.954545     0.953846     1.000000
# 4        0.826923      0.800000     0.756757     0.772727     0.666667
# ..            ...           ...          ...          ...          ...
# 339      0.694444      0.490566     0.518519     0.192308     0.254237
# 340      0.469388      0.351852     0.428571     0.283333     0.245283
# 341      0.790323      0.634615     0.716981     0.564103     0.688525
# 342      0.112903      0.184615     0.098361     0.065574     0.113208
# 343      0.583333      0.545455     0.538462     0.571429     0.523810
#
#      years_old_6  ...  years_pre_birth_3  years_pre_birth_4  \
# 0       0.421053  ...           0.151515           0.181818
# 1       0.168831  ...           0.166667           0.081081
# 2       0.275862  ...           0.000000           0.000000
# 3       0.852941  ...           0.545455           0.523810
# 4       0.516129  ...           0.363636           0.323529
# ..           ...  ...                ...                ...
# 339     0.265625  ...           0.045455           0.023810
# 340     0.238095  ...           0.056604           0.038462
# 341     0.471429  ...           0.254902           0.218182
# 342     0.073529  ...           0.066667           0.027027
# 343     0.403509  ...           0.166667           0.140000
#
#      years_pre_birth_5  years_pre_birth_6  years_pre_birth_7  \
# 0             0.000000           0.000000           0.000000
# 1             0.000000           0.000000           0.000000
# 2             0.000000           0.000000           0.000000
# 3             0.588235           0.485714           0.480000
# 4             0.414634           0.218750           0.000000
# ..                 ...                ...                ...
# 339           0.019231           0.021739           0.000000
# 340           0.039216           0.068966           0.000000
# 341           0.093750           0.076923           0.033333
# 342           0.050000           0.081081           0.068966
# 343           0.177778           0.047619           0.071429
#
#      years_pre_birth_8  years_pre_birth_9  years_pre_birth_10  \
# 0             0.000000           0.000000            0.000000
# 1             0.000000           0.000000            0.000000
# 2             0.000000           0.000000            0.000000
# 3             0.000000           0.000000            0.000000
# 4             0.000000           0.000000            0.000000
# ..                 ...                ...                 ...
# 339           0.137931           0.066667            0.085714
# 340           0.062500           0.130435            0.000000
# 341           0.227273           0.000000            0.000000
# 342           0.000000           0.000000            0.000000
# 343           0.000000           0.130435            0.000000
#
#      mean_millennial_recognition  mean_gen_z_recognition
# 0                       0.517602                0.268378
# 1                       0.209632                0.062439
# 2                       0.553481                0.244176
# 3                       0.830967                0.540097
# 4                       0.623149                0.372787
# ..                           ...                     ...
# 339                     0.127727                0.060286
# 340                     0.130290                0.060126
# 341                     0.469101                0.148085
# 342                     0.092154                0.052923
# 343                     0.356767                0.093943
#
# [344 rows x 28 columns]
