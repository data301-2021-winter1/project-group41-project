# %%
import pandas as pd
import seaborn as sns

nintiesRecData = pd.read_csv("../../data/raw/recognition_by_generation.csv")

nintiesRecData['avg_across_gen'] = (nintiesRecData['mean_millennial_recognition']*nintiesRecData['mean_gen_z_recognition'])/2 

nintiesRecData_sortedByMillTop = (
    nintiesRecData.sort_values(by=['mean_millennial_recognition'])
    .drop('mean_gen_z_recognition',1)
    .drop('avg_across_gen',1)
    .reset_index(drop=True)
)

nintiesRecData_sortedByMillTop.head(10)
# Out:
# C:\Users\anish\AppData\Local\Temp/ipykernel_9800/3739204165.py:9: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   nintiesRecData.sort_values(by=['mean_millennial_recognition'])
#             artist                     song  mean_millennial_recognition
# 0      Jesus Jones         Real, Real, Real                     0.043351
# 1          PM Dawn      I'd Die Without You                     0.048410
# 2   Tracie Spencer               This House                     0.049024
# 3        Tara Kemp           Hold You Tight                     0.050395
# 4     Taylor Dayne  Love Will Lead You Back                     0.054324
# 5  Sweet Sensation      If Wishes Came True                     0.054886
# 6   Gloria Estefan   Coming Out Of The Dark                     0.057876
# 7           H-Town        Knockin' Da Boots                     0.059737
# 8           Prince      Diamonds And Pearls                     0.063532
# 9     Damn Yankees              High Enough                     0.065579
